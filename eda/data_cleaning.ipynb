# %% [markdown]
# Collecting Data

# %%
import pandas as pd
import requests as r
import sql_functions as sf
import psycopg2

# %%
schema = 'capstone_anglianwater'
engine = sf.get_engine()

# %% [markdown]
# ### UK bottled water Production (1998-2023)

# %% [markdown]
# Output of mineral/bottled water by UK manufacturers in GBP Million.

# %%
production_columns = ['period', 'value']
production = pd.read_csv('data/bottled_water_production_UK.csv',
                     names=production_columns, 
                     skiprows = 8)

# %%
production.head()
# Out:
#   period   value
# 0   1998  2820.2
# 1   1999  3187.3
# 2   2000  3057.8
# 3   2001  3145.7
# 4   2002  3240.8

# %%
production_new = production[production['period'].str.len() == 8]
production_new['date']=pd.to_datetime(production_new['period'], format='%Y %b', dayfirst=True, errors='coerce')
production_new.loc[:, 'year'] = production_new.loc[:, 'date'].dt.year.astype(str)
production_new.loc[:, 'month'] = production_new.loc[:, 'date'].dt.month.astype(str)
# Out:
# /var/folders/_g/dvhb__pn0x1fmlk_x3wg4ttc0000gn/T/ipykernel_64595/195879008.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   production_new['date']=pd.to_datetime(production_new['period'], format='%Y %b', dayfirst=True, errors='coerce')
# /var/folders/_g/dvhb__pn0x1fmlk_x3wg4ttc0000gn/T/ipykernel_64595/195879008.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   production_new.loc[:, 'year'] = production_new.loc[:, 'date'].dt.year.astype(str)
# /var/folders/_g/dvhb__pn0x1fmlk_x3wg4ttc0000gn/T/ipykernel_64595/195879008.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   production_new.loc[:, 'month'] = production_new.loc[:, 'date'].dt.month.astype(str)

# %%
uk_bottled_water_production = production_new.iloc[:,[2,1]]

# %%
uk_bottled_water_production
# Out:
#           date  value
# 128 1998-01-01  183.0
# 129 1998-02-01  196.4
# 130 1998-03-01  243.0
# 131 1998-04-01  247.7
# 132 1998-05-01  287.9
# ..         ...    ...
# 434 2023-07-01  647.1
# 435 2023-08-01  648.4
# 436 2023-09-01  632.8
# 437 2023-10-01  598.0
# 438 2023-11-01  632.5
#
# [311 rows x 2 columns]

# %% [markdown]
# ### UK bottled water  price (1996-2023)

# %% [markdown]
# Output price inflation of mineral waters and other bottled waters. Base year for calculation is 2015 (=100)

# %%
bw_price_columns = ['period', 'value']
bw_price = pd.read_csv('data/bottled_water_production_price_UK.csv', 
                     names=bw_price_columns, 
                     skiprows = 8)

# %%
bw_price.head()
# Out:
#   period  value
# 0   2009   95.6
# 1   2010   94.8
# 2   2011   94.8
# 3   2012  104.2
# 4   2013  107.5

# %%
bw_price_new = bw_price[bw_price['period'].str.len() == 8]
bw_price_new['date']=pd.to_datetime(bw_price_new['period'], format='%Y %b', dayfirst=True, errors='coerce')
bw_price_new.loc[:, 'year'] = bw_price_new.loc[:, 'date'].dt.year.astype(str)
bw_price_new.loc[:, 'month'] = bw_price_new.loc[:, 'date'].dt.month.astype(str)
# Out:
# /var/folders/_g/dvhb__pn0x1fmlk_x3wg4ttc0000gn/T/ipykernel_64595/1213447139.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bw_price_new['date']=pd.to_datetime(bw_price_new['period'], format='%Y %b', dayfirst=True, errors='coerce')
# /var/folders/_g/dvhb__pn0x1fmlk_x3wg4ttc0000gn/T/ipykernel_64595/1213447139.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bw_price_new.loc[:, 'year'] = bw_price_new.loc[:, 'date'].dt.year.astype(str)
# /var/folders/_g/dvhb__pn0x1fmlk_x3wg4ttc0000gn/T/ipykernel_64595/1213447139.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bw_price_new.loc[:, 'month'] = bw_price_new.loc[:, 'date'].dt.month.astype(str)

# %%
uk_bottled_water_inflation_clean = bw_price_new.iloc[:,[2,1]]
uk_bottled_water_inflation_clean
# Out:
#           date  value
# 75  1996-01-01   77.0
# 76  1996-02-01   80.6
# 77  1996-03-01   78.6
# 78  1996-04-01   79.3
# 79  1996-05-01   79.4
# ..         ...    ...
# 406 2023-08-01  120.6
# 407 2023-09-01  119.8
# 408 2023-10-01  119.6
# 409 2023-11-01  122.8
# 410 2023-12-01  124.4
#
# [336 rows x 2 columns]

# %% [markdown]
# ### Top selling UK bottled water brands

# %% [markdown]
#  Mineral contents, number of consumers and prices of most commonly bought brands in the UK.

# %%
bottled_water_nutritions = pd.read_csv('data/Bottled_water_references - Sheet1.csv', )

# %%
bottled_water_nutritions
# Out:
#                   gibrand                  owner  consumers       type  \
# 0   Highland Spring Water        Highland Spring    6132550      still
# 1                   Evian                 Danone    5939000      still
# 2           Buxton Spring                 Nestle    5141140      still
# 3                  Volvic                 Danone    4489750      still
# 4                   Tesco                  Tesco    3748080      still
# 5          San Pellegrino                 Nestle    2049090  sparkling
# 6             Sainsbury's            Sainsbury's    1954960      still
# 7                    Asda                   Asda    1764320      still
# 8           Harrogate Spa                 Danone    1444100      still
# 9               Pure Life                 Nestle    1354900      still
# 10              Morrisons  Morrison Supermarkets    1253890      still
# 11              Aqua Pura            Source Alma    1234740      still
# 12             Strathmore                AG Barr    1074840      still
# 13                 Vittel                 Nestle    1018200      still
# 14     Glaceau Smartwater              Coca Cola     960110      still
# 15                Perrier                 Nestle     811710  sparkling
# 16          Brecon Carreg          Brecon Carreg     785830      still
# 17                    M&S                    M&S     785570      still
#
#     price_per_liter_gbp  sulfate_so42  bicarbonate_hco  calcium_ca++  \
# 0                  0.60           5.3            150.0          40.5
# 1                  1.00          14.0            360.0          80.0
# 2                  0.60          13.0            248.0          55.0
# 3                  0.70           9.0             74.0          12.0
# 4                  0.20          11.0             25.0          11.0
# 5                  1.10         401.0            244.0         166.0
# 6                  0.20           5.0            160.0          40.0
# 7                  0.20          10.0            166.0          40.0
# 8                  2.00          13.0            215.0          57.0
# 9                  0.40           9.7            184.6          59.0
# 10                 0.33          10.0            228.0          50.0
# 11                 0.50          14.0             55.0          19.0
# 12                 1.70           1.0            145.0          75.0
# 13                 0.50         400.0            384.0         240.0
# 14                 1.00          77.0             10.0           1.0
# 15                 1.85          33.0            430.0         160.0
# 16                 0.39           9.0            225.0          55.0
# 17                 0.40          13.0            135.0          42.0
#
#     chloride_cl-  total_dissolved_solids_at_180c  magnesium_mg2  sodium_na+  \
# 0            6.1                           170.0           10.1         5.6
# 1           10.0                           345.0           26.0         6.5
# 2           37.0                           280.0           19.0        24.0
# 3           15.0                           130.0            8.0        12.0
# 4           14.0                             NaN            3.0        10.0
# 5           49.6                           853.0           49.5        30.0
# 6           10.0                           220.0           20.0        10.0
# 7           11.0                           228.0           14.0         6.0
# 8           37.0                             NaN           19.0         8.0
# 9           18.1                           248.0           10.0        11.9
# 10          74.0                           418.0           14.0        76.0
# 11          15.0                           110.0            7.0        11.0
# 12         155.0                           453.0           15.0        56.0
# 13           NaN                          1084.0           42.0         5.2
# 14           1.0                             NaN           20.0         NaN
# 15          22.0                           480.0            4.2         9.5
# 16           9.0                           210.0           15.0         5.0
# 17          10.0                           135.0            9.0        12.0
#
#     silica_sio2  nitrate_no3-  potassium_k+   fluoride_f-   ph  \
# 0           NaN           3.1            0.7          NaN  NaN
# 1          15.0           3.8            1.0          NaN  NaN
# 2           NaN           0.1            1.0          NaN  7.4
# 3          32.0           7.3            6.0          NaN  NaN
# 4           NaN           NaN            NaN          NaN  NaN
# 5           7.3           2.8            2.1          0.5  NaN
# 6           NaN           1.0            0.0          NaN  7.2
# 7           NaN           8.0            3.0          NaN  7.8
# 8           NaN           1.0            NaN          NaN  7.0
# 9           NaN           NaN            1.2          NaN  6.5
# 10          NaN           0.4            7.5          NaN  NaN
# 11          NaN          20.0            3.0          NaN  6.4
# 12          NaN           5.0            2.2          0.1  NaN
# 13          NaN           4.4            NaN          NaN  NaN
# 14          NaN           NaN            5.0          1.0  7.0
# 15          NaN           NaN            NaN          NaN  NaN
# 16          7.0           3.5            0.5          NaN  7.6
# 17          NaN           8.0            1.0          NaN  7.4
#
#                  remark
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12      carbonate caco3
# 13                  NaN
# 14  not published in UK
# 15            carbonate
# 16                  NaN
# 17                  NaN

# %%
new_table = 'uk_bottled_water_production'
if engine!=None:
    try:
        uk_bottled_water_production.to_sql(name=new_table, # Name of SQL table variable
                        con=engine, # Engine or connection
                        schema=schema,
                        if_exists='replace', # Drop the table before inserting new values 
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {new_table} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
else:
    print('No engine')
# Out:
# The uk_bottled_water_production table was imported successfully.

# %%
new_table = 'uk_bottled_water_nutrition'
if engine!=None:
    try:
        bottled_water_nutritions.to_sql(name=new_table, # Name of SQL table variable
                        con=engine, # Engine or connection
                        schema=schema,
                        if_exists='replace', # Drop the table before inserting new values 
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {new_table} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
else:
    print('No engine')
# Out:
# The uk_bottled_water_nutrition table was imported successfully.

# %%
new_table = 'uk_bottled_water_inflation'
if engine!=None:
    try:
        uk_bottled_water_inflation_clean.to_sql(name=new_table, # Name of SQL table variable
                        con=engine, # Engine or connection
                        schema=schema,
                        if_exists='replace', # Drop the table before inserting new values 
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {new_table} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
else:
    print('No engine')
# Out:
# The uk_bottled_water_inflation table was imported successfully.
